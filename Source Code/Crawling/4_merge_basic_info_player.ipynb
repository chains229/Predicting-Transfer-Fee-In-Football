# %%
import pandas as pd

players = pd.read_csv('C:/Users/Dell/Downloads/Work/TTDL/Đồ án/Data/Obtaining_players_and_teams/players_transfermarket.csv')
basic_info = pd.read_csv('C:/Users/Dell/Downloads/Work/TTDL/Đồ án/Data/Basic_info_player/basic_info.csv')

basic_info_with_link = pd.merge(players, basic_info, left_on=['player','team'], right_on=['name', 'team'])
basic_info_with_link
# Out:
#        Unnamed: 0_x                                       link  \
# 0                 0         /david-de-gea/profil/spieler/59377
# 1                 1        /jack-butland/profil/spieler/128899
# 2                 2           /tom-heaton/profil/spieler/34130
# 3                 3   /lisandro-martinez/profil/spieler/480762
# 4                 4      /raphael-varane/profil/spieler/164770
# ...             ...                                        ...
# 10749            22       /aidan-simmons/profil/spieler/867763
# 10750            23        /kusini-yengi/profil/spieler/708099
# 10751            24    /nathanael-blair/profil/spieler/1023268
# 10752            25    /zachary-sapsford/profil/spieler/703657
# 10753            26  /alexander-badolato/profil/spieler/957230
#
#                    player                      team  Unnamed: 0_y  \
# 0            David de Gea         Manchester United             0
# 1            Jack Butland         Manchester United             1
# ...

# %%
basic_info_with_link.to_csv('C:/Users/Dell/Downloads/Work/TTDL/Đồ án/Data/Basic_info_player/basic_info_with_link.csv')
